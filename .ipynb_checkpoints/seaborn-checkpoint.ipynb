# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("flights") 
data = data.pivot("month", "year", "passengers")

# Heatmap
sns.heatmap(data=data, annot=True, fmt="d", cmap="YlGnBu")

plt.show()
# Out:
# C:\Users\Casper\AppData\Local\Temp\ipykernel_20248\1479115063.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   data = data.pivot("month", "year", "passengers")

# %%
data.info
# Out:
# <bound method DataFrame.info of year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("flights")

# Line plot
sns.lineplot(data=data, x="year", y="passengers")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("iris")

# Swarm plot
sns.swarmplot(x="species", y="petal_length", data=data) # spişiz

plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("titanic")

# Bar plot
sns.countplot(data=data, x="class")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("tips")

# Scatter plot
sns.scatterplot(data=data, x="total_bill", y="tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("titanic")

# Facet grid
g = sns.FacetGrid(data, col="sex")

g.map(sns.histplot, "age")
plt.show()

# %%
import seaborn as sns

# İris veriseti yüklenir
iris = sns.load_dataset("iris")

# Species sütununa göre veriler gruplandırılır
g = sns.clustermap(iris.drop("species", axis=1), cmap="coolwarm", standard_scale=1)

# Grafiği ekrana bastır
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("iris")

# Histogram
sns.histplot(data=data, x="sepal_length")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek veri
data = sns.load_dataset("tips")

# Violin plot
sns.violinplot(x="day", y="total_bill", data=data)
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="white")

df = sns.load_dataset("penguins")

g = sns.JointGrid(data=df, x="body_mass_g", y="bill_depth_mm", space=0)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((2200, 6800), (10, 25)),
             thresh=0, levels=100, cmap="rocket")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/animation.py:887: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# Örnek bir veri seti oluşturma
data = pd.DataFrame({
    'age_group': np.repeat(['18-30', '31-45', '46-60', '61+'], 100),
    'feedback_rating': np.random.randint(1, 6, 400)
})

# FacetGrid oluşturma
g = sns.FacetGrid(data, col="age_group", margin_titles=True)

# Grafik tipi
g.map(sns.histplot, "feedback_rating")
# Out:
# "\nAlice is a highly successful marketing executive at her job. \nHer company is preparing to launch a new product and Alice wants to conduct a market research to understand customers' opinions about the product.\n For this purpose, she wants to analyze the opinions of customers of different age groups about the product.\n\nAlice decides to analyze her data with the Seaborn library and wants to create a graph that shows the different interpretations by age group. \nShe will be able to create separate graphics for different age groups by using the facetgrid function.\n\n"
